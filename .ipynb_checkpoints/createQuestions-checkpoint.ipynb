# %%
import scipy
import numpy as np
import json

import tensorflow
import keras
from watson_developer_cloud import NaturalLanguageUnderstandingV1
from watson_developer_cloud.natural_language_understanding_v1 \
  import Features, KeywordsOptions, EntitiesOptions

# %%
#Load credentials from file (Store credentials in json format)
with open('credentials.json') as f:
    data = json.load(f)
url = data["url"]
username = data["username"]
password = data["password"]

# %%
natural_language_understanding = NaturalLanguageUnderstandingV1(
  username=username,
  password=password,
  version='2018-03-16')

response = natural_language_understanding.analyze(
  url='http://www.latimes.com/politics/la-na-pol-court-baker-wedding-20180604-story.html',
  features=Features(
    keywords=KeywordsOptions(
        sentiment=False,
        emotion=False,
        limit=20),
    entities=EntitiesOptions(
        sentiment=False,
        emotion=False,
        limit=20)))

print(json.dumps(response, indent=2))
# Out:
# {
#   "retrieved_url": "http://www.latimes.com/politics/la-na-pol-court-baker-wedding-20180604-story.html",
#   "entities": [
#     {
#       "text": "Justice Anthony M. Kennedy",
#       "relevance": 0.769828,
#       "disambiguation": {
#         "dbpedia_resource": "http://dbpedia.org/resource/Anthony_Kennedy",
#         "subtype": [
#           "Politician",
#           "Judge"
#         ],
#         "name": "Anthony Kennedy"
#       },
#       "count": 7,
#       "type": "Person"
#     },
#     {
#       "text": "Supreme Court",
#       "relevance": 0.741584,
#       "count": 7,
#       "type": "Organization"
#     },
#     {
#       "text": "Phillips",
#       "relevance": 0.490001,
#       "count": 6,
#       "type": "Person"
#     },
#     {
#       "text": "Becket Fund for Religious Liberty",
#       "relevance": 0.38491,
#       "disambiguation": {
#         "dbpedia_resource": "http://dbpedia.org/resource/The_Becket_Fund_for_Religious_Liberty",
#         "subtype": [],
#         "name": "The Becket Fund for Religious Liberty"
#       },
#       "count": 1,
#       "type": "Organization"
#     },
#     {
#       "text": "Colorado",
#       "relevance": 0.315196,
#       "disambiguation": {
#         "subtype": [
#           "StateOrCounty"
#         ]
#       },
#       "count": 2,
#       "type": "Location"
#     },
#     {
#       "text": "Mark Rienzi",
#       "relevance": 0.300339,
#       "count": 3,
#       "type": "Person"
#     },
#     {
#       "text": "state\u2019s Civil Rights Commission",
#       "relevance": 0.295018,
#       "count": 1,
#       "type": "Organization"
#     },
#     {
#       "text": "Alliance Defending Freedom",
#       "relevance": 0.249341,
#       "count": 1,
#       "type": "Organization"
#     },
#     {
#       "text": "president",
#       "relevance": 0.237646,
#       "count": 1,
#       "type": "JobTitle"
#     },
#     {
#       "text": "California",
#       "relevance": 0.232406,
#       "disambiguation": {
#         "dbpedia_resource": "http://dbpedia.org/resource/California",
#         "subtype": [
#           "PoliticalDistrict",
#           "AdministrativeDivision",
#           "Appellation",
#           "GovernmentalJurisdiction",
#           "USState",
#           "WineRegion",
#           "StateOrCounty"
#         ],
#         "name": "California"
#       },
#       "count": 1,
#       "type": "Location"
#     }
#   ],
#   "language": "en",
#   "usage": {
#     "text_units": 1,
#     "text_characters": 3039,
#     "features": 2
#   },
#   "keywords": [
#     {
#       "text": "Anthony M. Kennedy",
#       "relevance": 0.904033
#     },
#     {
#       "text": "same-sex couples",
#       "relevance": 0.8784
#     },
#     {
#       "text": "Christian conservatives",
#       "relevance": 0.844361
#     },
#     {
#       "text": "gay rights cases",
#       "relevance": 0.843807
#     },
#     {
#       "text": "public accommodations law",
#       "relevance": 0.830572
#     },
#     {
#       "text": "wedding cake",
#       "relevance": 0.821534
#     },
#     {
#       "text": "Federal law forbids",
#       "relevance": 0.815416
#     },
#     {
#       "text": "Arizona-based Alliance Defending",
#       "relevance": 0.802732
#     },
#     {
#       "text": "custom wedding cake",
#       "relevance": 0.80142
#     },
#     {
#       "text": "sexual orientation",
#       "relevance": 0.79853
#     },
#     {
#       "text": "Civil Rights Commission",
#       "relevance": 0.78712
#     },
#     {
#       "text": "same-sex marriages",
#       "relevance": 0.774818
#     },
#     {
#       "text": "same-sex marriage",
#       "relevance": 0.739338
#     },
#     {
#       "text": "same-sex couple",
#       "relevance": 0.731888
#     },
#     {
#       "text": "religious belief",
#       "relevance": 0.695546
#     },
#     {
#       "text": "religious exemptions",
#       "relevance": 0.691567
#     },
#     {
#       "text": "undue disrespect",
#       "relevance": 0.691229
#     },
#     {
#       "text": "gay persons",
#       "relevance": 0.688935
#     },
#     {
#       "text": "business owners",
#       "relevance": 0.684329
#     },
#     {
#       "text": "open market",
#       "relevance": 0.678954
#     }
#   ]
# }
